-- %%
-- Ejercicio 01- Lab01- Juan Diego Gaitan Haskell
--09/03/2026

--1. Escribe el codigo correspondiente para concatenar dos listas: [1,2,3] y [4,5]

lista1 = [1, 2, 3]
lista2 = [4, 5]
resultado = lista1 ++ lista2
resultado 
-- resultado = [1,2,3,4,5]
-- Out:
-- [1,2,3,4,5]

-- %%
-- 2. Revisa el tipo de una expresión usando :t, por ejemplo
 :t True
 :t "Hola mundo"
 :t [1,2,3]

--Output
--True :: Bool
--"Hola mundo" :: String
--[1,2,3] :: forall {a}. Num a => [a]
-- Out:
-- True :: Bool
-- "Hola mundo" :: String
-- [1,2,3] :: forall {a}. Num a => [a]

-- %%
--Pregunta Teórica:  ¿Qué significa que Haskell sea un lenguaje fuertemente tipado y evaluado perezosamente?
--Fuertemente tipado: Haskell necesita la correcta definición e interacción de mismo tipos y previene operaciones inválidas entre tipos diferentes.
--Evaluación perezosa: Haskell no evalúa expresiones hasta que son necesarias, lo que permite construir programas más eficientes y trabajar con estructuras potencialmente infinitas.

-- %%
--3. Define las siguientes funciones:

--Devuelve el doble de un número.
doble :: Int -> Int
doble x = x*2
doble 15

--doble 15 = 30


--Devuelve True si la edad ingresada es mayor o igual a 18.
esMayorEdad :: Int -> Bool
esMayorEdad x = x>= 18
esMayorEdad 17

--esMayorEdad False

--Calcula el área de un círculo dado su radio.
areaCirculo :: Float -> Float
areaCirculo x = (x^2)* pi
areaCirculo 1

--areaCirculo = 3.14...
--Pista: Usa pi que ya está definido en Haskell.

--Pregunta de reflexión: ¿Qué diferencias encuentras entre los tipos Int y Float?
--Int: Representa enteros, tiene un rango limitado dependiente de la implementación. 
---2147483648 a 2147483647 en Int32.

--Float: Representa números de punto flotante (con parte decimal).
--Usa precisión simple (IEEE 754 de 32 bits) y puede redondear.
--Ejemplo: 3.14, -0.001.
-- Out:
-- 30
-- False
-- 3.1415927
